# %%
import torch 
import torch.nn as nn
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:285
#     281                     raise err
#     283         kernel32.SetErrorMode(prev_error_mode)
# --> 285     _load_dll_libraries()
#     286     del _load_dll_libraries
#     289 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     290     # Libraries can either be in
#     291     # path/nvidia/lib_folder/lib or
#     292     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     293     # path/lib_folder/lib
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:268, in _load_dll_libraries()
#     264     err = ctypes.WinError(last_error)
#     265     err.strerror += (
# ...
